# %%
import os
import sys

# %%
sys.path.append("/Workspace/Repos/bejmafei@gmail.com/iasi-housing-market-analysis")
from databricks.run_medallion_pipeline import run_full_pipeline

# %%
run_full_pipeline(start_page=1, end_page=10)

# %%
# %sql
select 
  *
from silver.clean_listings
limit 10;

# %%
# %sql
select 
  count(*) as nr_apps,
  zona
from silver.clean_listings
group by zona
order by count(*) desc;
