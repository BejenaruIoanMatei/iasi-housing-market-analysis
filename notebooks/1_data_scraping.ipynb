# %%
# %pip install requests
# %pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup
import requests
import csv

# %%
url = "https://www.storia.ro/"

response = requests.get(url)

if response.status_code == 200:
    print('success')
else:
    print(f"failure, {response.status_code}")
# Out:
# failure, 403

# %%
url = "https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)

print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")
print(soup)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

BASE_URL = "https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi"
NUMAR_PAGINI = 80
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9,ro;q=0.8"
}

data_colectata = []

for pagina in range(1, NUMAR_PAGINI + 1):
    url_curent = f"{BASE_URL}?page={pagina}"
    print(f"Pagina {pagina}: {url_curent} ...")
    
    try:
        response = requests.get(url_curent, headers=HEADERS)
        
        if response.status_code != 200:
            print(f"Eroare la pagina {pagina} (Cod: {response.status_code})")
            continue
            
        soup = BeautifulSoup(response.content, 'html.parser')
        
        anunturi = soup.find_all('article')
        
        if not anunturi:
            print("Nu s au mai gasit anunturi.")
            break
            
        for card in anunturi:
            item = {}

            titlu_tag = card.find('h3') 
            if not titlu_tag:
                titlu_tag = card.find('span', {'data-cy': 'listing-item-title'})
            
            item['Titlu'] = titlu_tag.get_text(strip=True) if titlu_tag else "Titlu Necunoscut"
            
            pret_text = "N/A"
            spans = card.find_all('span')
            for span in spans:
                text = span.get_text(strip=True)
                if '€' in text:
                    pret_text = text
                    break
            item['Pret_Raw'] = pret_text
            
            link_tag = card.find('a', href=True)
            item['Link'] = "https://www.storia.ro" + link_tag['href'] if link_tag else "N/A"
            
            full_text = card.get_text(separator=' | ')
            item['Full_Description'] = full_text
                        
            data_colectata.append(item)
            
        print(f"Pagina {pagina} success. Total anunturi pana acum: {len(data_colectata)}")
        
        time.sleep(random.uniform(2, 4))
        
    except Exception as e:
        print(f"Eroare la pagina {pagina}: {e}")

df = pd.DataFrame(data_colectata)

def curata_pret(p):
    if pd.isna(p) or p == "N/A": return None
    clean = p.replace(' ', '').replace('€', '').replace(',', '.')
    try:
        return float(clean)
    except:
        return None

df['Pret_EUR'] = df['Pret_Raw'].apply(curata_pret)

print(df[['Titlu', 'Pret_EUR', 'Link']].head())

nume_fisier = "2_imobiliare_iasi_raw.csv"
df.to_csv(nume_fisier, index=False)
# Out:
# Pagina 1: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=1 ...
# Pagina 1 success. Total anunturi pana acum: 36
# Pagina 2: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=2 ...
# Pagina 2 success. Total anunturi pana acum: 73
# Pagina 3: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=3 ...
# Pagina 3 success. Total anunturi pana acum: 110
# Pagina 4: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=4 ...
# Pagina 4 success. Total anunturi pana acum: 147
# Pagina 5: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=5 ...
# Pagina 5 success. Total anunturi pana acum: 183
# Pagina 6: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=6 ...
# Pagina 6 success. Total anunturi pana acum: 220
# Pagina 7: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=7 ...
# Pagina 7 success. Total anunturi pana acum: 257
# Pagina 8: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=8 ...
# Pagina 8 success. Total anunturi pana acum: 294
# Pagina 9: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=9 ...
# Pagina 9 success. Total anunturi pana acum: 331
# Pagina 10: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=10 ...
# Pagina 10 success. Total anunturi pana acum: 368
# Pagina 11: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=11 ...
# Pagina 11 success. Total anunturi pana acum: 404
# Pagina 12: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=12 ...
# Pagina 12 success. Total anunturi pana acum: 441
# Pagina 13: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=13 ...
# Pagina 13 success. Total anunturi pana acum: 478
# Pagina 14: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=14 ...
# Pagina 14 success. Total anunturi pana acum: 515
# Pagina 15: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=15 ...
# Pagina 15 success. Total anunturi pana acum: 552
# Pagina 16: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=16 ...
# Pagina 16 success. Total anunturi pana acum: 589
# Pagina 17: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=17 ...
# Pagina 17 success. Total anunturi pana acum: 626
# Pagina 18: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=18 ...
# Pagina 18 success. Total anunturi pana acum: 663
# Pagina 19: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=19 ...
# Pagina 19 success. Total anunturi pana acum: 700
# Pagina 20: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=20 ...
# Pagina 20 success. Total anunturi pana acum: 737
# Pagina 21: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=21 ...
# Pagina 21 success. Total anunturi pana acum: 774
# Pagina 22: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=22 ...
# Pagina 22 success. Total anunturi pana acum: 811
# Pagina 23: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=23 ...
# Pagina 23 success. Total anunturi pana acum: 845
# Pagina 24: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=24 ...
# Pagina 24 success. Total anunturi pana acum: 882
# Pagina 25: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=25 ...
# Pagina 25 success. Total anunturi pana acum: 918
# Pagina 26: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=26 ...
# Pagina 26 success. Total anunturi pana acum: 955
# Pagina 27: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=27 ...
# Pagina 27 success. Total anunturi pana acum: 991
# Pagina 28: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=28 ...
# Pagina 28 success. Total anunturi pana acum: 1028
# Pagina 29: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=29 ...
# Pagina 29 success. Total anunturi pana acum: 1065
# Pagina 30: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=30 ...
# Pagina 30 success. Total anunturi pana acum: 1102
# Pagina 31: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=31 ...
# Pagina 31 success. Total anunturi pana acum: 1137
# Pagina 32: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=32 ...
# Pagina 32 success. Total anunturi pana acum: 1174
# Pagina 33: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=33 ...
# Pagina 33 success. Total anunturi pana acum: 1211
# Pagina 34: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=34 ...
# Pagina 34 success. Total anunturi pana acum: 1248
# Pagina 35: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=35 ...
# Pagina 35 success. Total anunturi pana acum: 1285
# Pagina 36: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=36 ...
# Pagina 36 success. Total anunturi pana acum: 1322
# Pagina 37: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=37 ...
# Pagina 37 success. Total anunturi pana acum: 1359
# Pagina 38: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=38 ...
# Pagina 38 success. Total anunturi pana acum: 1396
# Pagina 39: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=39 ...
# Pagina 39 success. Total anunturi pana acum: 1433
# Pagina 40: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=40 ...
# Pagina 40 success. Total anunturi pana acum: 1470
# Pagina 41: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=41 ...
# Pagina 41 success. Total anunturi pana acum: 1507
# Pagina 42: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=42 ...
# Pagina 42 success. Total anunturi pana acum: 1544
# Pagina 43: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=43 ...
# Pagina 43 success. Total anunturi pana acum: 1581
# Pagina 44: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=44 ...
# Pagina 44 success. Total anunturi pana acum: 1618
# Pagina 45: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=45 ...
# Pagina 45 success. Total anunturi pana acum: 1651
# Pagina 46: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=46 ...
# Pagina 46 success. Total anunturi pana acum: 1685
# Pagina 47: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=47 ...
# Pagina 47 success. Total anunturi pana acum: 1722
# Pagina 48: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=48 ...
# Pagina 48 success. Total anunturi pana acum: 1750
# Pagina 49: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=49 ...
# Pagina 49 success. Total anunturi pana acum: 1787
# Pagina 50: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=50 ...
# Pagina 50 success. Total anunturi pana acum: 1824
# Pagina 51: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=51 ...
# Pagina 51 success. Total anunturi pana acum: 1861
# Pagina 52: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=52 ...
# Pagina 52 success. Total anunturi pana acum: 1898
# Pagina 53: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=53 ...
# Pagina 53 success. Total anunturi pana acum: 1935
# Pagina 54: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=54 ...
# Pagina 54 success. Total anunturi pana acum: 1972
# Pagina 55: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=55 ...
# Pagina 55 success. Total anunturi pana acum: 2009
# Pagina 56: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=56 ...
# Pagina 56 success. Total anunturi pana acum: 2046
# Pagina 57: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=57 ...
# Pagina 57 success. Total anunturi pana acum: 2083
# Pagina 58: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=58 ...
# Pagina 58 success. Total anunturi pana acum: 2120
# Pagina 59: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=59 ...
# Pagina 59 success. Total anunturi pana acum: 2157
# Pagina 60: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=60 ...
# Pagina 60 success. Total anunturi pana acum: 2194
# Pagina 61: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=61 ...
# Pagina 61 success. Total anunturi pana acum: 2231
# Pagina 62: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=62 ...
# Pagina 62 success. Total anunturi pana acum: 2268
# Pagina 63: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=63 ...
# Pagina 63 success. Total anunturi pana acum: 2305
# Pagina 64: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=64 ...
# Pagina 64 success. Total anunturi pana acum: 2342
# Pagina 65: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=65 ...
# Pagina 65 success. Total anunturi pana acum: 2379
# Pagina 66: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=66 ...
# Pagina 66 success. Total anunturi pana acum: 2416
# Pagina 67: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=67 ...
# Pagina 67 success. Total anunturi pana acum: 2453
# Pagina 68: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=68 ...
# Pagina 68 success. Total anunturi pana acum: 2490
# Pagina 69: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=69 ...
# Pagina 69 success. Total anunturi pana acum: 2526
# Pagina 70: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=70 ...
# Pagina 70 success. Total anunturi pana acum: 2563
# Pagina 71: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=71 ...
# Pagina 71 success. Total anunturi pana acum: 2600
# Pagina 72: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=72 ...
# Pagina 72 success. Total anunturi pana acum: 2637
# Pagina 73: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=73 ...
# Pagina 73 success. Total anunturi pana acum: 2674
# Pagina 74: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=74 ...
# Pagina 74 success. Total anunturi pana acum: 2711
# Pagina 75: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=75 ...
# Pagina 75 success. Total anunturi pana acum: 2748
# Pagina 76: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=76 ...
# Pagina 76 success. Total anunturi pana acum: 2785
# Pagina 77: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=77 ...
# Pagina 77 success. Total anunturi pana acum: 2822
# Pagina 78: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=78 ...
# Pagina 78 success. Total anunturi pana acum: 2853
# Pagina 79: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=79 ...
# Pagina 79 success. Total anunturi pana acum: 2890
# Pagina 80: https://www.storia.ro/ro/rezultate/vanzare/apartament/iasi/iasi?page=80 ...
# Pagina 80 success. Total anunturi pana acum: 2927
#               Titlu  Pret_EUR  \
# 0  Titlu Necunoscut       NaN
# 1  Titlu Necunoscut       NaN
# 2  Titlu Necunoscut       NaN
# 3  Titlu Necunoscut       NaN
# 4  Titlu Necunoscut       NaN
#
#                                                 Link
# 0  https://www.storia.ro/ro/oferta/etaj-1-apartam...
# 1  https://www.storia.ro/ro/oferta/apartament-de-...
# 2  https://www.storia.ro/ro/oferta/oportunitate-u...
# 3  https://www.storia.ro/ro/oferta/podul-de-fier-...
# 4  https://www.storia.ro/ro/oferta/apartament-1-c...

# %% [markdown]
# ### OBS:
#
# -   Ne asumam faptul ca scraping-ul se realizeaza de pe pagina principala de anunturi si ca nu se deschide fiecare anunt in parte pentru scraping. De asta descriile sunt incomplete, dar contin strictul necesar cum ar fi locatia, pretul, numar de camere, vechimea blocului, etc.
